# %% [markdown]
# ## Installation des dépendances

# %% [markdown]
# ## Imports

# %%
import io
import re
from typing import Dict, List, Optional
from dataclasses import dataclass
from PyPDF2 import PdfReader
from pathlib import Path

# %% [markdown]
# ## Définition des classes et fonctions

# %%
@dataclass
class ParsedPage:
    """Résultat du parsing d'une page."""
    page_number: int
    markdown_content: str
    char_count: int
    word_count: int
    has_tables: bool
    extraction_quality: float  # 0-1

# %%
def clean_text_from_redundant_elements(
    text: str,
    headers: List[str],
    footers: List[str],
    page_patterns: List[str]
) -> str:
    """Nettoie le texte des éléments redondants."""
    cleaned = text
    
    # Supprimer les headers
    for header in headers:
        cleaned = cleaned.replace(header, "")
    
    # Supprimer les footers
    for footer in footers:
        cleaned = cleaned.replace(footer, "")
    
    # Supprimer les numéros de page
    for pattern in page_patterns:
        cleaned = re.sub(pattern, "", cleaned)
    
    return cleaned

# %%
def _is_likely_header(line: str, all_lines: List[str], index: int) -> bool:
    """Détecte si une ligne est probablement un header."""
    if len(line) > 80:
        return False
    
    if len(line) < 3:
        return False
    
    if line.isupper() and len(line) > 5:
        return True
    
    if re.match(r"^(\d+\.)+\s*\w+|^[IVXLC]+\.\s*\w+", line):
        return True
    
    if len(line) < 50 and not re.search(r"[.!?,;:]$", line):
        if index + 1 < len(all_lines):
            next_line = all_lines[index + 1].strip()
            if not next_line or len(next_line) > len(line):
                return True
    
    return False

# %%
def _determine_header_level(text: str) -> int:
    """Détermine le niveau de header (1-4)."""
    if re.match(r"^\d+\.\d+\.\d+", text):
        return 4
    if re.match(r"^\d+\.\d+", text):
        return 3
    if re.match(r"^\d+\.", text):
        return 2
    
    if text.isupper():
        if len(text) < 20:
            return 1
        return 2
    
    return 3

# %%
def _detect_table_structure(text: str) -> bool:
    """Détecte si le texte contient des structures tabulaires."""
    patterns = [
        r"\|.*\|.*\|",
        r"\t.*\t.*\t",
        r"^\s*\S+\s{3,}\S+\s{3,}\S+",
    ]
    
    for pattern in patterns:
        if re.search(pattern, text, re.MULTILINE):
            return True
    
    return False

# %%
def _calculate_extraction_quality(raw_text: str, cleaned_text: str) -> float:
    """Calcule un score de qualité de l'extraction."""
    if not raw_text:
        return 0.0
    
    conservation_ratio = len(cleaned_text) / len(raw_text) if raw_text else 0
    
    if not cleaned_text:
        return 0.0
    
    normal_chars = len(
        re.findall(
            r"[a-zA-Z0-9àâäéèêëïîôùûüçÀÂÄÉÈÊËÏÎÔÙÛÜÇ\s.,!?;:\-\'\"()\[\]{}]",
            cleaned_text,
        )
    )
    
    char_quality = normal_chars / len(cleaned_text) if cleaned_text else 0
    quality = conservation_ratio * 0.3 + char_quality * 0.7
    
    return min(1.0, max(0.0, quality))

# %%
def _text_to_markdown(text: str, page_num: int) -> str:
    """Convertit du texte brut en Markdown structuré."""
    if not text or not text.strip():
        return ""
    
    lines = text.split("\n")
    markdown_lines = []
    in_list = False
    
    for i, line in enumerate(lines):
        stripped = line.strip()
        
        if not stripped:
            if in_list:
                in_list = False
            markdown_lines.append("")
            continue
        
        if _is_likely_header(stripped, lines, i):
            level = _determine_header_level(stripped)
            markdown_lines.append(f"\n{'#' * level} {stripped}\n")
            continue
        
        if re.match(r"^[\-\•\*\→\►]\s+", stripped):
            in_list = True
            content = re.sub(r"^[\-\•\*\→\►]\s+", "", stripped)
            markdown_lines.append(f"- {content}")
            continue
        
        if re.match(r"^\d+[\.\)]\s+", stripped):
            in_list = True
            markdown_lines.append(stripped)
            continue
        
        markdown_lines.append(stripped)
    
    result = "\n".join(markdown_lines)
    result = re.sub(r"\n{3,}", "\n\n", result)
    
    return result.strip()

# %%
def pdf_text_parser(pdf_path: str) -> Dict:
    """Extrait le texte d'un PDF et le convertit en Markdown."""
    print(f"📝 Extraction texte par parsing: {pdf_path}")
    
    # Lire le fichier PDF
    with open(pdf_path, 'rb') as f:
        pdf_bytes = f.read()
    
    # Configuration par défaut
    headers = []
    footers = []
    page_patterns = [r"Page\s+\d+"]
    
    try:
        pdf_file = io.BytesIO(pdf_bytes)
        pdf_reader = PdfReader(pdf_file)
        total_pages = len(pdf_reader.pages)
        
        parsed_pages: List[ParsedPage] = []
        all_markdown_parts: List[str] = []
        
        for page_num in range(1, total_pages + 1):
            page = pdf_reader.pages[page_num - 1]
            
            try:
                raw_text = page.extract_text() or ""
                cleaned_text = clean_text_from_redundant_elements(
                    raw_text, headers, footers, page_patterns
                )
                
                markdown_content = _text_to_markdown(cleaned_text, page_num)
                
                char_count = len(markdown_content)
                word_count = len(markdown_content.split())
                has_tables = _detect_table_structure(cleaned_text)
                quality = _calculate_extraction_quality(raw_text, cleaned_text)
                
                parsed_page = ParsedPage(
                    page_number=page_num,
                    markdown_content=markdown_content,
                    char_count=char_count,
                    word_count=word_count,
                    has_tables=has_tables,
                    extraction_quality=quality,
                )
                
                parsed_pages.append(parsed_page)
                
                if markdown_content.strip():
                    all_markdown_parts.append(markdown_content)
                    
            except Exception as e:
                print(f"   ⚠️ Erreur page {page_num}: {str(e)}")
                continue
        
        full_markdown = "\n\n---\n\n".join(all_markdown_parts)
        
        total_chars = sum(p.char_count for p in parsed_pages)
        total_words = sum(p.word_count for p in parsed_pages)
        avg_quality = (
            sum(p.extraction_quality for p in parsed_pages) / len(parsed_pages)
            if parsed_pages
            else 0
        )
        
        print(f"   ✅ {len(parsed_pages)} pages parsées")
        print(f"   📊 {total_chars} caractères, {total_words} mots")
        print(f"   📊 Qualité moyenne: {avg_quality:.0%}")
        
        return {
            "error": None,
            "parsed_pages": parsed_pages,
            "parsed_markdown": full_markdown,
            "parsing_stats": {
                "pages_parsed": len(parsed_pages),
                "total_chars": total_chars,
                "total_words": total_words,
                "average_quality": round(avg_quality, 2),
            },
        }
        
    except Exception as e:
        return {
            "error": f"Erreur lors du parsing: {str(e)}",
            "parsed_pages": [],
            "parsed_markdown": "",
        }

# %% [markdown]
# ## Configuration du fichier PDF

# %%
# Spécifiez le nom du fichier PDF dans le dossier ressources/
pdf_filename = "main.pdf"  # Changez ceci avec le nom de votre fichier PDF
pdf_path = Path("ressources") / pdf_filename

# Vérifier que le fichier existe
if not pdf_path.exists():
    print(f"❌ Fichier non trouvé: {pdf_path}")
    print(f"\nFichiers disponibles dans ressources/:")
    ressources_dir = Path("ressources")
    if ressources_dir.exists():
        for file in ressources_dir.iterdir():
            if file.is_file():
                print(f"  - {file.name}")
else:
    print(f"✅ Fichier trouvé: {pdf_path}")
# Out:
# ✅ Fichier trouvé: ressources\main.pdf

# %% [markdown]
# ## Extraction du PDF vers Markdown

# %%
# Exécuter l'extraction
result = pdf_text_parser(str(pdf_path))

if result["error"]:
    print(f"\n❌ Erreur: {result['error']}")
else:
    print("\n✅ Extraction réussie!")
    print(f"\nStatistiques:")
    stats = result["parsing_stats"]
    print(f"  - Pages: {stats['pages_parsed']}")
    print(f"  - Caractères: {stats['total_chars']}")
    print(f"  - Mots: {stats['total_words']}")
    print(f"  - Qualité: {stats['average_quality']:.0%}")
# Out:
# 📝 Extraction texte par parsing: ressources\main.pdf
#    ✅ 80 pages parsées
#    📊 144926 caractères, 20447 mots
#    📊 Qualité moyenne: 98%
#
# ✅ Extraction réussie!
#
# Statistiques:
#   - Pages: 80
#   - Caractères: 144926
#   - Mots: 20447
#   - Qualité: 98%

# %% [markdown]
# ## Affichage du contenu Markdown

# %%
# Afficher le contenu Markdown
if result["parsed_markdown"]:
    print("\n" + "="*50)
    print("CONTENU MARKDOWN EXTRAIT:")
    print("="*50 + "\n")
    print(result["parsed_markdown"])
else:
    print("Aucun contenu extrait.")
# Out:
# ==================================================
# CONTENU MARKDOWN EXTRAIT:
# ==================================================
#
# Cahier des charges
#
# ### Table des matières
#
# Anthony Menghi & Mehdi Ghoulam 1 04/11/2024
#
# ---
#
# Cahier des charges
#
# ### Chapitre 1
#
# Mindlet : une application d’apprentissage
#
# ### collaborative et innovante
#
# Mindlet est un réseau social innovant conçu pour révolutionner l’apprentissage collaboratif.
# En combinant des technologies d’intelligence artificielle avancées avec des fonctionnalités sociales,
# Mindlet rend l’apprentissage plus interactif, accessible et adapté aux besoins actuels. Grâce à un en-
# vironnement intuitif et dynamique, où la collaboration et la personnalisation sont centrales, Mindlet
# offreuneexpériencemoderneetconviviale,oùl’apprentissagedevientcollectif,ludiqueetengageant.
# Notre mission : Transformer la manière d’apprendre en exploitant la puissance de l’IA et les in-
# teractions sociales. Mindlet permet aux utilisateurs de s’approprier leurs apprentissages en fonction
# de leurs préférences et de leurs objectifs, que ce soit pour réviser des notions, explorer de nouvelles
# connaissances ou consolider leurs acquis.
#
# ### 1.1 Concept principal
#
# Mindlet permet aux utilisateurs de créer des « collections » de cartes d’apprentissage, appelées
# Flashcards , qu’ils peuvent partager, commenter, et enrichir avec leurs amis. L’application va plus
# loin encore en intégrant des modes d’apprentissage variés – flashcards, quiz, et jeux de correspon-
# dance – chacun conçu pour stimuler différentes fonctions cérébrales et maximiser la rétention des
# informations. Cette approche diversifiée permet d’activer plusieurs régions du cerveau et renforcer
# la mémorisation par répétition, la lecture active, et l’engagement social.
#
# #### 1.1.1 Les méthodes d’apprentissage et leurs capacités
#
# —Flashcards : Favorisent la mémoire visuelle et la répétition espacée, permettant une révision
# efficace des informations.
# —Quiz :Engagent la mémoire de rappel et renforcent la rétention à long terme en posant des
# questions directes.
# —Match (jeu de correspondance) : Stimule les capacités de reconnaissance et de logique en
# associant des notions aux définitions, créant une dimension ludique qui accroît l’engagement.
# Anthony Menghi & Mehdi Ghoulam 2 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# ### 1.2 Approche neuroscientifique et pédagogique
#
# Mindlet s’appuie sur des principes de l’apprentissage pour maximiser l’impact pédagogique. En
# diversifiant les modes d’apprentissage, l’application permet d’activer à la fois la mémoire de travail,
# la mémoire à long terme, et la mémoire visuelle, ce qui aide les utilisateurs à mieux intégrer les
# connaissances. De plus, la dimension sociale de l’application motive les utilisateurs à apprendre
# ensemble, créant ainsi un environnement stimulant qui améliore la persévérance et la motivation.
# Mindlet ambitionne de devenir un outil de référence pour les apprenants de tous âges, en permet-
# tant de combiner apprentissage autonome et esprit de communauté. Avec des méthodes d’apprentis-
# sage variées et une dimension sociale forte (groupes, messagerie, défis collectifs), Mindlet transforme
# l’apprentissage en une expérience captivante, qui stimule l’esprit et le plaisir d’apprendre.
# Anthony Menghi & Mehdi Ghoulam 3 04/11/2024
#
# ---
#
# Cahier des charges
#
# ### Chapitre 2
#
# ### Cadre du projet et analyse
#
# ### 2.1 Présentation de l’équipe
#
# Ce projet à été crée et imaginé par Anthony Menghi et Mehdi Ghoulam, deux étudiants en Mas-
# ter Informatique, spécialisés dans le développement full stack web et mobile. Ils sont également
# étudiants-entrepreneurs au sein du pôle PEPITE de Corse.
# Bien que l’équipe soit composée de seulement deux membres, chacun joue un rôle actif dans
# toutes les dimensions du projet, couvrant des domaines variés tels que le développement frontend,
# le développement backend, le design graphique, l’ergonomie, la gestion de bases de données, la ges-
# tion de projet, l’intelligence artificielle, ainsi que la communication et le marketing. Malgré leurs
# spécialisations respectives, les deux membres disposent de compétences leur permettant d’intervenir
# sur tous les aspects techniques et stratégiques de l’initiative.
# Cependant, il convient de noter que Mehdi Ghoulam possède une expertise approfondie dans les
# domaines du DevOps, de l’architecture système, des réseaux, du développement backend et de la
# gestion des bases de données. De son côté, Anthony Menghi se concentre principalement sur les as-
# pects visuels du projet, notamment le design graphique et l’ergonomie. Il prend également en charge
# le développement frontend, le développement de l’intelligence artificielle, ainsi que l’élaboration de
# la stratégie de communication et de marketing.
#
# ### 2.2 Objectifs du projet
#
# #### 2.2.1 Pédagogiques
#
# —Favoriser un apprentissage collaboratif et engagé :
# Créer une plateforme immersive où les utilisateurs apprennent de manière autonome ou en
# collaboration avec leurs pairs, rendant l’expérience d’apprentissage plus interactive, dyna-
# mique et sociale.
# —Automatiser la création de contenus pédagogiques avec l’IA :
# Exploiter l’intelligence artificielle pour générer automatiquement des flashcards, des quiz et
# Anthony Menghi & Mehdi Ghoulam 4 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# d’autres outils pédagogiques, adaptés aux besoins spécifiques des utilisateurs, afin de réduire
# le temps et les efforts requis pour la préparation des supports d’apprentissage.
# —Encourager l’interaction entre utilisateurs pour favoriser motivation et progres-
# sion:
# Proposer des fonctionnalités sociales comme les défis, les groupes d’apprentissage, les com-
# mentaires et les classements, afin de stimuler l’émulation, renforcer la motivation et encou-
# rager l’apprentissage collectif.
#
# #### 2.2.2 Technologies
#
# —Développer une plateforme multiplateforme accessible sur tous les appareils :
# Assurer une expérience fluide sur iOS, Android, Windows, MacOS, Linux et le web, grâce à
# des technologies de développement cross-platform, garantissant une accessibilité maximale.
# —Intégrer l’intelligence artificielle pour améliorer l’adaptabilité de l’apprentissage :
# Développer des systèmes d’IA capables d’adapter les contenus d’apprentissage en fonction
# des besoins individuels de chaque utilisateur, afin de personnaliser l’expérience et d’optimiser
# l’efficacité de l’apprentissage.
# —Optimiserl’interfaceutilisateurpourgarantiruneexpérienceintuitiveetagréable :
# Concevoir une interface simple, intuitive et visuellement attractive, tout en assurant des per-
# formances rapides et fluides pour une navigation optimale sur tous les supports.
# —Assurer la sécurité et la confidentialité des données des utilisateurs :
# Implémenter des mesures de sécurité robustes pour protéger les données personnelles et
# garantir la conformité aux réglementations (RGPD) en matière de confidentialité.
#
# #### 2.2.3 Entrepreneuriaux
#
# —Valider et pérenniser le modèle économique de Mindlet :
# Explorer différentes sources de revenus, telles que des abonnements premium, des fonction-
# nalités payantes, des partenariats avec des établissements éducatifs, ou la publicité ciblée,
# afin d’assurer la viabilité financière du projet à long terme.
# —Développer une communauté active et engagée autour de l’application :
# Attirer et fidéliser une large base d’utilisateurs en créant une communauté dynamique d’ap-
# prenants qui participent activement à la création de contenu, aux défis et aux discussions,
# favorisant ainsi une croissance organique de la plateforme.
# —Obtenir des partenaires pour accélérer le développement et l’expansion de l’ap-
# plication :
# Rechercher des partenaires stratégiques pour soutenir le développement de Mindlet, en met-
# tant en avant son potentiel de croissance, son modèle innovant et son impact sur l’éducation.
# —Positionner Mindlet comme un leader dans le domaine de l’apprentissage colla-
# boratif numérique :
# Construire une forte reconnaissance de marque à travers des campagnes marketing efficaces,
# descollaborationsavecdesinfluenceurs,etdespartenariatsavecdesinstitutionsacadémiques
# pour faire de Mindlet un outil incontournable dans le secteur éducatif.
# Anthony Menghi & Mehdi Ghoulam 5 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# ### 2.3 Applications concurrentes ou voisines
#
# Il est important d’analyser les applications concurrentes ou similaires afin de se positionner stra-
# tégiquement sur le marché, d’identifier les bonnes pratiques et d’évaluer ce qui fonctionne moins
# bien. Pour cela, nous avons exploré différents réseaux sociaux tels que TikTok, YouTube et X, dans
# le but d’identifier les applications les plus utilisées.
# Dans le domaine de l’apprentissage numérique, plusieurs applications et plateformes proposent
# des solutions similaires ou voisines à Mindlet. Toutefois, aucune d’entre elles ne réunit à la fois
# l’aspect collaboratif, l’utilisation de l’intelligence artificielle et une interface simple et ludique pour
# stimuler l’engagement. Voici une analyse des principales applications concurrentes ou voisines :
#
# ### Application Description Forces
#
# Anki Application de révision basée sur des
# flashcards avec répétition espacée, par-
#
# ### ticulièrement populaire chez les étu-
#
# diants.Méthode de révision éprouvée, flexibi-
# lité dans la création de cartes.
# Quizlet Plateforme pour créer des flashcards,
#
# ### participeràdesquizetexplorerdescol-
#
# lections collaboratives.Interface conviviale, grande commu-
# nauté, options de personnalisation.
# Duolingo Application ludique pour l’apprentis-
#
# ### sage des langues, avec des leçons
#
# courtes et gamification poussée.Gamification immersive, apprentissage
# addictif, large choix de langues.
#
# ### RemNote Outil hybride de prise de notes et fla-
#
# shcards avec répétition espacée.Intégration des flashcards dans la prise
# de notes, révision automatisée.
# Memrise Application d’apprentissage des
#
# ### langues avec répétition et vidéos
#
# immersives.Apprentissage contextuel, approche lu-
# dique.
# Table 2.1 – Comparaison des applications concurrentes ou voisines de Mindlet
#
# #### 2.3.1 Analyse
#
# On peut constater que de nombreuses applications se rapprochent de Mindlet, mais aucune ne
# parvient à combiner tous les besoins essentiels : fonctionnalités collaboratives, réseau social, utili-
# sation avancée de l’intelligence artificielle, interface ludique et divers méthodes d’apprentissage.
# Nous nous sommes néanmoins inspirés des points forts de chacune de ces applications. Par
# exemple, c’est grâce à Anki que l’idée initiale de Mindlet a vu le jour. Quizlet nous a inspirés avec
# son approche proposant plusieurs méthodes d’apprentissage au sein d’une seule collection. Duolingo,
# Anthony Menghi & Mehdi Ghoulam 6 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# avec son interface conviviale et sa gamification ludique (notamment à travers sa mascotte emblé-
# matique). RemNote, bien qu’orienté principalement vers la prise de notes de cours, propose des
# fonctionnalités intéressantes comme l’importation de fichiers et la création de flashcards. RemNote
# vise également une approche «tout-en-un», mais sans intégrer la dimension sociale. Enfin, Memrise
# nous a démontré l’importance d’adopter des méthodes amusantes et engageantes pour apprendre.
# Cependant,danstoutescesapplications,l’utilisationdel’intelligenceartificiellerestelimitée.Par
# exemple, il n’est pas possible d’effectuer des actions complexes, comme gérer de grandes collections,
# demander à l’IA d’ajouter de nouveaux concepts, ou importer et analyser de volumineux fichiers
# PDF. C’est précisément ce que Mindlet aspire à résoudre, tout en combinant le meilleur de chaque
# solution existante.
#
# ### 2.4 Personas : Cibler les utilisateurs de Mindlet
#
# Pour mieux comprendre les besoins, les attentes et les comportements des différents types d’uti-
# lisateurs, il est essentiel de définir des personas. Un persona est une représentation semi-fictionnelle
# d’un utilisateur typique basée sur des données démographiques, des comportements et des besoins
# spécifiques.VoicitroispersonasdétailléspourMindlet,afindemieuxorienterlastratégiemarketing,ledéve-
# loppement produit et la communication.
# Anthony Menghi & Mehdi Ghoulam 7 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# #### 2.4.1 Personas utilisateurs
#
# Persona Profil Objectifs Comportement et be-
#
# ### soins
#
# Angèle,
# étudianteÉtudiante de 18 ans
#
# ### en première année de
#
# médecine. Elle cherche
# des outils pour gé-
# rer efficacement de
#
# ### grandes quantités
#
# d’informations, alliant
#
# ### révision ludique et
#
# efficacité.Organiser ses révisions de
# manière interactive et va-
# riée, retenir des notions
# complexes avec des outils
#
# ### dynamiques,collaboreravec
#
# ### ses camarades pour se pré-
#
# parer aux examens.Utilise principalement son
# smartphone pour réviser,
# partage des ressources avec
#
# ### ses camarades, préfère des
#
# outils interactifs comme les
# flashcards et les quiz.
# Lucas,
#
# ### profes-
#
# sionnelProfessionnel en fi-
#
# ### nance suivant une
#
# formation continue. Il
# souhaite optimiser son
# temps d’apprentissage
#
# ### pour acquérir des
#
# compétences utiles à
#
# ### son développement
#
# professionnel.Apprendre efficacement
# tout en gérant son emploi
#
# ### du temps chargé, retenir
#
# et appliquer des concepts
#
# ### professionnels, accéder à
#
# ### des contenus personnalisés
#
# adaptés à son domaine.Utilise des outils accessibles
# sur plusieurs supports, ap-
#
# ### prend de manière autonome
#
# ### mais apprécie les échanges
#
# avec ses collègues, recherche
# des fonctionnalités de suivi
# des progrès.
# Sophie,
#
# ### ensei-
#
# gnanteEnseignante en ma-
# thématiques dans un
#
# ### lycée.Elle souhaite
#
# rendre ses cours plus
# interactifs et enga-
#
# ### geants grâce à des
#
# outils numériques.Créerdesressourcesinterac-
# tives pour ses élèves, suivre
# leurs progrès en temps réel,
#
# ### encourager l’apprentissage
#
# collaboratif et autonome.Partage des contenus via
# des plateformes collabora-
# tives, souhaite des outils
#
# ### ludiques pour motiver ses
#
# élèves, préfère un système
# de suivi des performances.
# Table 2.2 – Personas utilisateurs de Mindlet
#
# #### 2.4.2 Conclusion
#
# L’analyse des profils révèle la diversité des besoins et attentes des utilisateurs potentiels de
# Mindlet. Qu’il s’agisse d’étudiants comme Angèle, en quête de méthodes interactives pour simplifier
# leurs révisions, de professionnels comme Lucas, désireux d’optimiser leur apprentissage malgré un
# emploi du temps chargé, ou encore d’enseignants comme Sophie, cherchant à captiver leurs élèves,
# Mindlet s’affirme comme une solution flexible et adaptable.
# Anthony Menghi & Mehdi Ghoulam 8 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# ### 2.5 Analyse SWOT (Forces, Faiblesses, Opportunités, Me-
#
# ### naces)
#
# L’analyse SWOT est essentielle pour établir une stratégie marketing claire et efficace en iden-
# tifiant les atouts de Mindlet, tout en prenant en compte ses vulnérabilités et les possibilités de
# croissance.
#
# ### Forces
#
# —Innovation technologique : La combinaison de l’IA, de l’apprentissage collaboratif et
# de la gamification distingue Mindlet des autres applications d’apprentissage. L’IA permet
# de personnaliser l’apprentissage en générant automatiquement des flashcards adaptées aux
# besoins de chaque utilisateur.
# —Multiplateforme : L’application est disponible sur une variété de plateformes (iOS, An-
# droid, Web, Windows, MacOS, Linux), permettant une large accessibilité.
# —Approche collaborative : Mindlet favorise l’apprentissage communautaire avec des défis,
# des partages de cartes, des groupes d’études, et une interaction constante entre utilisateurs.
# —Gamificationetmotivation: L’intégrationdejeux(Match,quiz)stimulel’engagementdes
# utilisateurs, rendant l’apprentissage non seulement plus intéressant mais aussi plus efficace.
#
# ### Faiblesses
#
# —Notoriété faible à ce jour : En tant que nouvelle application, Mindlet doit développer sa
# marque et gagner la confiance des utilisateurs.
# —Courbe d’apprentissage pour les utilisateurs non familiers avec la technologie :
# Certaines fonctionnalités peuvent être perçues comme complexes au début, en particulier
# pour les personnes moins technophiles.
# —Dépendance au contenu utilisateur : Le succès de l’application dépend en grande partie
# de la capacité des utilisateurs à créer, partager et enrichir des contenus de manière régulière.
#
# ### Opportunités
#
# —Croissance du marché de l’éducation en ligne : Avec la montée des plateformes d’ap-
# prentissage en ligne, Mindlet est bien positionné pour capter l’intérêt des étudiants, des
# professionnels en reconversion et des formateurs.
# —Développement de partenariats avec des institutions : En s’associant avec des uni-
# versités, écoles, entreprises et organisations d’apprentissage, Mindlet peut élargir son champ
# d’application et accroître sa crédibilité.
# —Expansion dans des niches spécifiques : Mindlet peut se diversifier en proposant des
# fonctionnalités ciblées pour des groupes particuliers comme les formateurs, les coachs, les
# chercheurs ou les créateurs de contenu éducatif.
# Anthony Menghi & Mehdi Ghoulam 9 04/11/2024
#
# ---
#
# Cahier des charges
#
# ### Menaces
#
# —Concurrenceélevée: DesapplicationsétabliescommeAnki,QuizletouDuolingodominent
# déjà le marché. Mindlet devra se différencier par des fonctionnalités uniques pour capter
# l’attention des utilisateurs.
# —Évolution rapide des technologies et des attentes : Le marché des technologies édu-
# catives évolue rapidement, ce qui signifie que Mindlet devra constamment innover pour ré-
# pondre aux attentes des utilisateurs.
# —Régulations sur les données personnelles : La gestion des données personnelles et la
# conformité au RGPD pourraient devenir un point de friction, en particulier dans le cadre de
# l’utilisation de l’IA.
#
# ### 2.6 Cibles principales
#
# —Étudiants :
# —Besoins : Apprendre de manière plus efficace, avec des outils qui augmentent leur réten-
# tion d’information (répétition espacée, flashcards, quizz, défis).
# —Comportements : Souvent à la recherche de moyens plus interactifs et motivants pour
# étudier, ils aiment partager des ressources avec leurs amis et participer à des jeux ou
# concours.
# —Professionnels et adultes en formation continue :
# —Besoins : Flexibilité, apprentissage personnalisé, ressources adaptées à des créneaux
# horaires réduits.
# —Comportements : Préférence pour des outils efficaces qui maximisent leur temps, per-
# mettant de réviser de manière autonome et structurée.
# —Enseignants et formateurs :
# —Besoins : Créer et partager des ressources, faciliter l’apprentissage collaboratif, suivre
# les progrès des étudiants.
# —Comportements : Cherchent des outils simples à utiliser pour leurs élèves, avec des
# fonctionnalités collaboratives et de suivi des performances.
# —Passionnés d’apprentissage continu :
# —Besoins : Outils diversifiés pour un apprentissage flexible et ludique, ainsi qu’une com-
# munauté pour échanger des connaissances.
# —Comportements : Recherche d’applications qui offrent une expérience personnalisée,
# gamifiée, et qui offrent un contenu infini à explorer.
# Valeurs de Mindlet :
# —Innovation et personnalisation : L’utilisation de l’IA pour proposer des cartes d’appren-
# tissage personnalisées et optimiser la méthode de révision de chaque utilisateur est au cœur
# de Mindlet.
# —Communauté et partage : Mindlet met un point d’honneur à favoriser l’entraide, la
# collaboration et le partage entre utilisateurs.
# —Accessibilité: L’applicationestdisponiblesurplusieursplateformes,cequipermetàchacun
# d’apprendre où et quand il le souhaite, avec un design simple et intuitif.
# Anthony Menghi & Mehdi Ghoulam 10 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# —Motivation : En intégrant des éléments ludiques et gamifiés (badges, défis, classement),
# Mindlet encourage une pratique continue et rend l’apprentissage plus attrayant.
#
# ### 2.7 Stratégie digitale
#
# SEO et content marketing :
# —Objectif : Attirer un public organique via des articles de blog optimisés pour les moteurs
# de recherche.
# —Actions :
# — Création d’un blog sur des sujets autour de l’apprentissage (répétition espacée, gamifica-
# tion de l’apprentissage, meilleures pratiques pour réviser, etc.).
# — Optimisation des pages de l’application pour le SEO afin de capter un trafic ciblé sur
# Google.
# Publicité sur les réseaux sociaux :
# —Objectif : Promouvoir Mindlet auprès de cibles spécifiques en utilisant les réseaux sociaux.
# —Actions :
# — Publicités vidéo et visuelles sur Instagram, Facebook, LinkedIn et TikTok montrant des
# témoignages d’utilisateurs et des démonstrations interactives.
# — Publicité ciblée sur les plateformes en fonction des groupes d’âge, d’intérêts (étudiants,
# professionnels) et de la géographie.
# Partenariats et influenceurs :
# —Objectif : Collaborer avec des influenceurs spécialisés en éducation, apprentissage et tech-
# nologie.
# —Actions :
# — Organiser des partenariats avec des influenceurs éducatifs pour des démonstrations en
# ligne.
# — Offrir des essais gratuits ou des fonctionnalités premium aux utilisateurs de ces commu-
# nautés.
# Campagnes d’emailing et newsletters :
# —Objectif : Créer une relation directe avec les utilisateurs et les inciter à revenir sur l’appli-
# cation.
# —Actions :
# — Envoi d’emails mensuels avec des conseils d’apprentissage, des annonces de nouveaux
# défis, ou des mises à jour de fonctionnalités.
# — Créer une séquence d’onboarding pour guider les nouveaux utilisateurs à travers les fonc-
# tionnalités clés de Mindlet.
#
# ### b. Stratégie de Fidélisation
#
# Programme de récompenses et de badges :
# —Objectif : Stimuler la fidélisation et encourager l’engagement des utilisateurs.
# —Actions :
# — Implémentation d’un système de points que les utilisateurs peuvent accumuler en créant
# des cartes, en participant à des défis ou en atteignant des objectifs de révision.
# Anthony Menghi & Mehdi Ghoulam 11 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# — Remise de badges et récompenses pour les utilisateurs les plus actifs ou ayant atteint des
# objectifs spécifiques.
# Gamification et compétitions :
# —Objectif : Rendre l’apprentissage encore plus motivant.
# —Actions :
# — Organiser des concours de révision ou des compétitions entre groupes d’étudiants, avec
# des classements publics.
# — Organiser des défis à thème pour maintenir l’engagement (ex : révision de la géographie
# européenne en 30 jours).
# Notifications push et suivi personnalisé :
# —Objectif : Garder les utilisateurs engagés et les inciter à revenir régulièrement.
# —Actions :
# — Notificationspushpersonnaliséessurlesprogrèsdel’utilisateur,luirappelantdecontinuer
# sa révision, d’essayer un quiz ou d’ajouter des cartes.
# — Feedback personnalisé sur les performances pour aider les utilisateurs à ajuster leurs
# stratégies d’apprentissage.
# Anthony Menghi & Mehdi Ghoulam 12 04/11/2024
#
# ---
#
# Cahier des charges
#
# ### Chapitre 3
#
# ### Besoins fonctionnels
#
# ### 3.1 Fonctionnalités essentielles
#
# #### 3.1.1 Création assistée par IA
#
# Les utilisateurs peuvent facilement créer des collections de cartes d’apprentissage (flashcards) en
# soumettant une simple requête, telle que : «Liste des capitales d’Europe». L’intelligence artificielle
# de Mindlet génère instantanément une série de cartes de révision pertinentes et adaptées au sujet
# demandé, offrant ainsi un gain de temps considérable tout en éliminant la nécessité de rechercher
# les informations manuellement.
#
# #### 3.1.2 Méthodes d’apprentissage diversifiées
#
# —Flashcards : Les cartes permettent un apprentissage basé sur la répétition espacée, une
# méthode prouvée pour améliorer la mémorisation à long terme. Chaque carte présente une
# question d’un côté et une réponse de l’autre, incitant l’utilisateur à se tester régulièrement.
# —Quiz :Les utilisateurs peuvent concevoir des quiz pour tester leurs connaissances sur un
# sujet donné. Ces quiz peuvent inclure des questions à choix multiples, des réponses ouvertes,
# ou des exercices de correspondance. Cela permet une auto-évaluation en temps réel pour
# mesurer la maîtrise des connaissances.
# —Match (Jeu de correspondance) : Cette fonctionnalité ludique permet aux utilisateurs
# d’associer des notions à leurs définitions. C’est un moyen efficace pour renforcer la compré-
# hension et la mémoire par l’interaction.
#
# #### 3.1.3 Apprentissage collaboratif
#
# —Collections collaboratives : Les collections de cartes peuvent être créées de manière col-
# laborative. Par exemple, un étudiant peut créer une collection basée sur ses cours, puis
# permettre à ses amis ou collègues de la compléter ou de la modifier. Les utilisateurs peuvent
# scanner des extraits de leurs livres ou cours pour enrichir le contenu, et d’autres peuvent
# contribuer avec des corrections ou ajouts via l’IA, rendant l’apprentissage plus dynamique.
# Anthony Menghi & Mehdi Ghoulam 13 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# —Défis et entraînements en groupe : Les utilisateurs ont la possibilité de lancer des
# défis d’apprentissage pour se mesurer à leurs amis ou à des groupes. Ces défis peuvent être
# basés sur des quiz, des jeux de correspondance ou des révisions de flashcards. Cela permet
# de renforcer l’aspect social de l’apprentissage et d’encourager une participation active. Les
# groupes d’étude peuvent se créer autour de différents sujets, favorisant l’entraide et le soutien
# mutuel.
# —Notifications et récompenses : Afin de stimuler l’engagement, l’application utilise des
# notifications push personnalisées pour rappeler aux utilisateurs de continuer leurs révisions,
# de tester leurs progrès, ou de participer à un défi. De plus, les utilisateurs peuvent gagner des
# badges ou des points de fidélité en fonction de leur activité et de leurs performances (nombre
# de cartes créées, de défis lancés, etc.). Ces récompenses virtuelles servent à maintenir la
# motivation et à encourager une participation continue.
#
# #### 3.1.4 Suivi des progrès et analytique
#
# —Suivi des progrès personnalisé : Mindlet offre un tableau de bord interactif permettant
# aux utilisateurs de suivre leurs progrès d’apprentissage au fil du temps. Chaque session
# d’apprentissage est enregistrée et des statistiques détaillées sont fournies, telles que le nombre
# de cartes révisées, le taux de réussite aux quiz, et les progrès réalisés dans les défis. Ce suivi
# personnalisé aide les utilisateurs à identifier leurs points faibles et à ajuster leurs méthodes
# d’apprentissage en conséquence.
# —Analytique avancée : L’IA de Mindlet analyse les performances des utilisateurs et fournit
# des suggestions personnalisées sur la manière d’améliorer leur apprentissage. Par exemple, si
# un utilisateur peine à mémoriser certaines cartes, l’application peut suggérer de revoir ces
# éléments plus fréquemment ou d’essayer une autre méthode d’apprentissage (comme le quiz
# ou le jeu de correspondance).
#
# #### 3.1.5 Partage social et communauté
#
# —Partage sur les réseaux sociaux : Les utilisateurs peuvent partager leurs progrès, leurs
# collectionsdecartesouleursrésultatsdedéfissurlesréseauxsociaux,renforçantainsil’aspect
# communautaire de Mindlet. Cela permet de promouvoir l’application tout en facilitant les
# interactions sociales autour de l’apprentissage.
# —Forums de discussion et groupes : Des forums et des groupes de discussion peuvent
# être créés autour de thèmes spécifiques (par exemple, préparation aux examens, révisions
# de cours). Les utilisateurs peuvent échanger des astuces d’apprentissage, poser des questions
# et partager des ressources supplémentaires. Cela contribue à construire une communauté
# d’apprentissage active et solidaire.
#
# #### 3.1.6 Fonctionnalités adaptatives et personnalisées
#
# —Personnalisation des contenus : En plus de l’assistance IA pour la création de cartes,
# les utilisateurs peuvent personnaliser leurs collections de cartes en ajoutant des images,
# des vidéos, des audios ou des liens vers des ressources externes (articles, vidéos éducatives,
# Anthony Menghi & Mehdi Ghoulam 14 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# etc.). Cela permet d’adapter le contenu aux préférences d’apprentissage de chaque utilisateur
# (visuel, auditif, kinesthésique).
# —Apprentissage adaptatif : L’application ajuste la fréquence et la difficulté des révisions en
# fonction des performances passées de l’utilisateur, permettant un apprentissage plus efficace.
# Par exemple, l’IA peut décider de montrer certaines cartes plus fréquemment si elles sont
# mal maîtrisées, ou de ralentir la révision de certaines cartes si l’utilisateur les connaît bien.
# Ce système de révision adaptative maximise l’efficacité de l’apprentissage.
#
# #### 3.1.7 Accessibilité et multi-plateformes
#
# —Disponibilité multiplateforme : Mindlet est conçu pour être accessible sur plusieurs pla-
# teformes : iOS, Android, Windows, macOS, Linux, et via un navigateur web. Les utilisateurs
# peuvent commencer leur révision sur leur smartphone, continuer sur leur tablette ou leur
# ordinateur de bureau, ce qui leur offre une flexibilité totale. Le système de synchronisation
# en temps réel permet de reprendre l’apprentissage où que l’on soit, à tout moment.
# —Accessibilité pour tous : L’application propose des fonctionnalités d’accessibilité pour les
# personnes ayant des besoins particuliers, comme des options de lecture audio pour les cartes,
# des contrastes de couleurs ajustables et une interface simple et intuitive pour les utilisateurs
# moins familiers avec les technologies.
#
# ### 3.2 Cas d’utilisations
#
# Le schéma ??présente l’ensemble des actions possibles pour un utilisateur au sein de l’applica-
# tion. Il est détaillé et organisé par catégories spécifiques. Par exemple, un utilisateur peut créer une
# collection et y ajouter des cartes (flashcards). Une fois sa collection complétée, il peut lancer une
# partie de jeu, telle que des flashcards, des quiz ou des jeux de correspondance.
# Anthony Menghi & Mehdi Ghoulam 15 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# Figure 3.1 – Schéma représentant les cas d’utilisations de l’application
# Anthony Menghi & Mehdi Ghoulam 16 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# ### 3.3 Maquettes fonctionnelles et arborescence
#
# Le schéma ??illustre l’architecture de l’expérience utilisateur (UX) globale de l’application,
# de la connexion initiale à la création de la collection, l’ajout de cartes, jusqu’à l’entraînement.
# L’objectif de ce diagramme est de guider la conception de la maquette fonctionnelle, en définissant
# les principes fondamentaux de l’architecture de l’information, l’arborescence de l’application, tout
# en offrant une vision claire et fluide de l’ergonomie cognitive et interactionnelle.
#
# ### Figure 3.2 – UX de l’application
#
# Le parcours utilisateur (UX) a été pensé selon les principes de l’efficacité cognitive, de la mi-
# nimisation des frictions et du design centré sur l’utilisateur (UCD). Il a été structuré pour que
# l’utilisateur atteigne ses objectifs (récompenses) en un maximum de trois clics, en s’appuyant sur
# des concepts de « low cognitive load » et « progressive disclosure ». Cette approche réduit le be-
# soin d’effort mental, en favorisant l’accès immédiat aux informations pertinentes et en éliminant les
# distractionsinutiles,cequiaméliorelaperformancedelanavigationetlasatisfactiondel’utilisateur.
# Exemples :
# — Lors de la première interaction avec l’application, du processus de création du compte au lan-
# cement de l’entraînement (récompense), l’utilisateur traverse uniquement trois pages, ce qui
# Anthony Menghi & Mehdi Ghoulam 17 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# suit la logique de "minimal user input" et de "quick wins" (récompenses rapides), garantissant
# ainsi une prise en main rapide et une courbe d’apprentissage réduite.
# — Après la connexion, la page d’accueil met en avant l’entraînement. Si l’utilisateur désire
# modifier une carte dans sa collection, il ne doit franchir que deux étapes avant d’atteindre
# l’interface de modification, ce qui illustre la notion d’"interaction directe" et de "one-click
# task", facilitant ainsi l’accès rapide aux actions essentielles.
# L’ergonomie a été optimisée grâce à l’utilisation des principes de "direct manipulation" et de
# "affordance visuelle", afin de rendre les éléments interactifs intuitifs et immédiatement compré-
# hensibles. Chaque interaction a été pensée selon la notion de "feedback immédiat", garantissant à
# l’utilisateur des retours visuels et sonores clairs, et le respect de la "consistance cognitive" tout au
# long du parcours.
# Dans cette optique, la maquette visuelle sur Figma a été conçue en respectant le concept de "pro-
# gressive disclosure", où seules les informations et actions pertinentes sont affichées à chaque étape,
# minimisant ainsi la surcharge cognitive. La maquette prend également en compte des principes de
# "mobile-first design" et de "responsive interaction", en offrant une expérience fluide et ergonomique,
# quelle que soit la taille de l’écran ou le dispositif utilisé.
# L’architecture de l’application s’appuie sur des "systèmes de navigation hiérarchiques" et de
# "funnel flow", où chaque étape conduit naturellement à la suivante, tout en évitant les "dead ends"
# ou les chemins sans issue. Cette approche permet de maximiser la rétention et la conversion, tout en
# garantissant un "user flow" optimal. Les choix typographiques et visuels sont également optimisés
# pour favoriser une "scannabilité" élevée et une lisibilité maximale, en appliquant des principes de
# "typography hierarchy" et "visual weight".
# Notre maquette Figma intègre ainsi les concepts d’UX et d’ergonomie, permettant de créer
# une maquette fonctionnelle et esthétique, tout en offrant une expérience utilisateur fluide, enga-
# geante et intuitive. La maquette de Mindlet a été minutieusement conçue en respectant la charte
# graphique préalablement définie. En tant qu’application innovante, Mindlet incarne cette philoso-
# phie en intégrant de manière fluide et cohérente les principes de l’UX design. Son interface, pensée
# pour être intuitive et agréable, s’appuie sur des pratiques modernes d’interaction et des principes
# fondamentaux de l’UI pour offrir une expérience utilisateur optimale.
#
# #### 3.3.1 Navigation innovante
#
# Mindlet se distingue par sa navigation fluide et moderne, inspirée des applications tendance et
# des gestes intuitifs des smartphones, tels que ceux utilisés sur Snapchat. L’application adopte une
# navigation mobile basée sur des mouvements de glissement de doigts, accompagnée de transitions
# animées qui créent une sensation de continuité, évitant ainsi le changement de page visible. Cette
# approche réduit les frictions de navigation et améliore la fluidité de l’expérience, créant un sen-
# timent de satisfaction instantanée à chaque interaction. L’animation des transitions renforce cette
# immersion en donnant l’impression que l’application "répond" aux actions de l’utilisateur de manière
# Anthony Menghi & Mehdi Ghoulam 18 04/11/2024
#
# ---
#
# Cahier des charges
# naturelle.
#
# #### 3.3.2 Principes clés de l’UI
#
# En plus des principes d’UX, l’interface de Mindlet intègre des concepts fondamentaux de design
# UI afin d’assurer une expérience utilisateur homogène et engageante.
# —Hiérarchie visuelle : L’organisation des informations suit une logique de clarté. Les élé-
# ments primaires, tels que les titres et les actions principales, sont mis en avant grâce à une
# typographie distincte, une taille accrue et un contraste de couleurs. Les informations secon-
# daires sont hiérarchisées par leur taille, couleur et position, facilitant ainsi la navigation et
# la compréhension de l’information en un coup d’œil.
# —Consistance :L’interfacemaintientunestructurecohérentesurtouslesécrans.Leséléments
# de design sont utilisés de manière uniforme pour chaque type d’action, permettant ainsi à
# l’utilisateur de comprendre rapidement l’interaction attendue, minimisant la courbe d’ap-
# prentissage et améliorant l’intuitivité. Les boutons, icônes et menus partagent des éléments
# visuels communs, renforçant la logique du parcours utilisateur.
# —Réactivité et performance : La réactivité de Mindlet est essentielle. Chaque action de
# l’utilisateur déclenche une réponse instantanée de l’application, avec des animations fluides
# et des temps de chargement réduits. Cela génère une sensation de contrôle et d’efficacité,
# ce qui rend l’expérience plus agréable et engageante. Les transitions entre les écrans sont
# animées pour réduire la sensation de délai et fournir un retour immédiat.
# —Accessibilité universelle : Mindlet intègre des fonctionnalités d’accessibilité pour répondre
# aux besoins d’un large éventail d’utilisateurs. L’application offre des boutons suffisamment
# larges pour être utilisés en mode "une main", tout en proposant des options de personnali-
# sation du contraste des couleurs, de la taille des polices et du mode sombre. Ces réglages
# permettent à chaque utilisateur d’adapter l’interface à ses préférences et besoins spécifiques.
# —Affordance :Lesélémentsinteractifsdel’interface(boutons,gestestactiles,etc.)sontconçus
# de manière à suggérer naturellement leur fonction. Par exemple, des icônes animées indiquent
# clairement les actions possibles, comme les balayages pour naviguer entre les cartes. De plus,
# les zones tactiles sont largement espacées pour éviter les erreurs de manipulation et offrir
# une interaction fluide.
# —Feedback visuel et sonore : Chaque interaction de l’utilisateur est immédiatement suivie
# d’un feedback visuel et sonore. Lorsqu’une action est effectuée, une animation visuelle (par
# exemple, un changement de couleur ou de forme) ou un léger son indique que l’action a été
# correctement prise en compte. Ce retour permet à l’utilisateur de se sentir en contrôle et
# renforce l’impression de réactivité de l’application.
# —Minimalisme et clarté : L’interface de Mindlet a été épurée au maximum, en ne montrant
# que les éléments essentiels pour éviter toute surcharge cognitive. L’espace blanc est utilisé de
# manière stratégique pour guider l’attention de l’utilisateur, permettant une hiérarchisation
# naturelle de l’information. Les icônes sont réduites à leur forme la plus simple, garantissant
# une navigation sans distraction.
# —Adaptabilité et responsive design : Mindlet offre une expérience homogène sur une large
# Anthony Menghi & Mehdi Ghoulam 19 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# gamme d’appareils, qu’il s’agisse d’un smartphone, d’une tablette ou d’un ordinateur. L’in-
# terface s’adapte dynamiquement aux différentes tailles d’écrans, en ajustant les éléments de
# manière fluide et cohérente. Les éléments interactifs sont optimisés pour le tactile, garantis-
# sant une expérience optimale quel que soit le dispositif.
# —Esthétique et plaisir visuel : Le design de Mindlet repose sur une palette de couleurs
# raffinée et des textures légères qui créent une atmosphère agréable. Des animations subtiles,
# telles que des effets de défilement et des transitions entre les écrans, apportent une sensa-
# tion de fluidité et de dynamisme sans alourdir l’interface. L’UI mise sur un design élégant,
# minimaliste et engageant qui crée un plaisir visuel tout au long de l’expérience.
# —Guidance contextuelle : L’interface intègre des éléments de guidance contextuelle pour
# faciliter la prise en main de l’application. Des infobulles discrètes, des tutoriels interactifs
# et des éléments d’interface qui se dévoilent de manière contextuelle guident l’utilisateur à
# chaque étape de son parcours, l’aidant ainsi à mieux comprendre l’application sans se sentir
# perdu ou submergé par les informations.
# En résumé, la maquette de Mindlet s’appuie sur des principes UI rigoureux qui garantissent non
# seulement une expérience fluide et agréable, mais aussi un design intelligent et réfléchi. L’application
# allie innovation, ergonomie et esthétique pour offrir une expérience immersive, intuitive et centrée
# sur l’utilisateur.
#
# ### 3.4 Modèle conceptuel de données
#
# Pour Mindlet, nous avons pensé au modèle de données présenté dans le schéma ??. Il représente
# les différentes entités et relations du système, organisées selon les fonctionnalités principales de
# l’application : gestion des utilisateurs, des collections de cartes, des sessions de jeu et des systèmes
# de messagerie.
# Anthony Menghi & Mehdi Ghoulam 20 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# ### Figure 3.3 – Modèle conceptuel de données
#
# Anthony Menghi & Mehdi Ghoulam 21 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# #### 3.4.1 Gestion des utilisateurs
#
# L’entité principale de cette partie est User, qui représente chaque utilisateur de l’application.
# —Champs importants :
# —userId: identifiant unique.
# —emailetusername : informations pour identifier chaque utilisateur.
# —roles: rôle de l’utilisateur ( USER,STAFF,OWNER).
# —Relations principales :
# — Un utilisateur peut avoir plusieurs collections, cartes, notifications ou messages.
# —UserLike : suit les "likes" entre utilisateurs.
# —Notifications : gère les alertes ou mises à jour envoyées aux utilisateurs.
#
# #### 3.4.2 Gestion des collections
#
# Les collections regroupent des cartes et permettent la collaboration entre utilisateurs.
# —Champs importants :
# —collectionId : identifiant unique.
# —ownerId : utilisateur propriétaire de la collection.
# —visibility : définit si une collection est publique ou privée.
# —Relations principales :
# — Une collection contient plusieurs cartes.
# — Elle peut être partagée avec des collaborateurs grâce aux entités :
# —CollectionInvitation : pour inviter des utilisateurs.
# —CollectionCollaborator : pour définir leurs droits (lecture/écriture).
#
# #### 3.4.3 Gestion des cartes
#
# Les cartes appartiennent aux collections et suivent l’apprentissage des utilisateurs.
# —Champs importants :
# —frontetback: contenu de la carte (recto/verso).
# —isActive : indique si la carte est active.
# —Relations principales :
# —CardProgression : suit l’état d’apprentissage de chaque carte (non vue, en apprentis-
# sage, apprise).
#
# #### 3.4.4 Gestion des jeux
#
# Les sessions de jeu utilisent des modes prédéfinis pour rendre l’apprentissage interactif.
# —Champs importants :
# —title: nom du mode de jeu.
# —isActive : indique si le mode est disponible.
# —Relations principales :
# —GameModeSetting : définit les paramètres des modes de jeu.
# —GameSession : relie un utilisateur, une collection et un mode de jeu à une session.
# Anthony Menghi & Mehdi Ghoulam 22 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# #### 3.4.5 Gestion des messageries
#
# Les utilisateurs peuvent discuter via des messages privés ou des groupes.
# —Relations principales :
# —DirectChat : relie deux utilisateurs pour une discussion privée.
# —GroupChat : permet les discussions en groupe avec des membres et des messages spé-
# cifiques.
#
# #### 3.4.6 Notifications et fonctionnalités
#
# —Feature : représente une fonctionnalité de l’application.
# —UserFeature : lie ces fonctionnalités aux utilisateurs pour les activer/désactiver.
#
# ### Résumé des relations clés
#
# — Un utilisateur peut posséder plusieurs collections, y collaborer, ou suivre sa progression sur
# les cartes.
# — Les utilisateurs peuvent communiquer entre eux ou recevoir des notifications liées à leurs
# interactions.
# Ce modèle de données est conçu pour être simple, flexible et évolutif, tout en répondant aux
# besoins de collaboration, d’apprentissage et de communication dans l’application.
# Anthony Menghi & Mehdi Ghoulam 23 04/11/2024
#
# ---
#
# Cahier des charges
#
# ### Chapitre 4
#
# ### Étude et choix des technologies
#
# Pourle développement deMindlet, nousavonsadopté unestack technologique moderne,orientée
# vers la flexibilité, la performance et la scalabilité. Cette section détaille nos choix technologiques
# pour le front-end, le back-end, les bases de données, ainsi que les solutions d’intelligence artificielle
# (IA). Chaque choix est justifié par une analyse approfondie des avantages et inconvénients par
# rapport aux autres technologies disponibles sur le marché.
#
# ### 4.1 Technologies front-end
#
# Pour le développement front-end, nous avons envisagé JavaScript ou plus précisement TypeS-
# cript.
# JavaScript : C’est le langage le plus populaire pour le développement web, soutenu par une vaste
# communauté et un écosystème riche. JavaScript est supporté par tous les navigateurs sans configu-
# ration supplémentaire, ce qui en fait un choix évident pour le développement front-end. Cependant,
# sa nature dynamique, sans typage statique, peut conduire à des erreurs difficiles à détecter lors de la
# maintenance de projets complexes. Cela peut entraîner des bugs subtils et compliquer le refactoring
# à grande échelle.
# TypeScript : TypeScript est une extension de JavaScript qui introduit le typage statique, ce qui
# améliore la lisibilité et la robustesse du code. Le typage statique aide à capturer les erreurs lors de
# la phase de compilation, réduisant ainsi les erreurs en production. De plus, TypeScript facilite le
# refactoring, ce qui est essentiel pour un projet évolutif comme le nôtre. Il permet également une
# meilleure intégration avec les outils de développement modernes (VS Code, ESLint, etc.) et facilite
# le développement d’équipes grâce à l’autocomplétion et aux vérifications de types.
# Anthony Menghi & Mehdi Ghoulam 24 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# #### 4.1.1 Comparaison des librairies front-end
#
# Librairie Rendu Performance Communauté Mode d’écriture
# React Calculs de diff
# entre le Virtual
#
# ### DOM et le DOM
#
# réel pour appliquer
#
# ### les changements
#
# efficacement.Performant, moins
#
# ### optimal pour des
#
# ### applications com-
#
# ### plexes sans bonnes
#
# pratiques.Grande commu-
# nauté, vaste quan-
#
# ### tité de ressources
#
# et de bibliothèques.Utilise JSX avec
# des hooks pour une
#
# ### programmation
#
# fonctionnelle.
# Vue.js Utilise un Virtual
#
# ### DOM simplifiée et
#
# ### une réactivité fine-
#
# grain.Très performant,
#
# ### mise à jour efficace
#
# grâce à la réactivité
#
# ### fine-grain.Communauté
#
# importanteStructure en com-
#
# ### posants basés sur
#
# des fichiers .vue di-
#
# ### visés en sections
#
# template, script, et
# style.
# Svelte Pas de Virtual
# DOM. Compilateur
#
# ### transformant le
#
# code en JavaScript.Performances ex-
# ceptionnelles grâce
#
# ### à l’absence de
#
# virtualisation.Communauté en
# forte croissance,
# bien que plus petite
#
# ### que celles de React
#
# et Vue.Code écrit de ma-
# nière déclarative,
# similaire à Vue,
# mais sans phase de
# virtualisation.
# Solid.js Utilise une réac-
#
# ### tivité fine-grain
#
# ### (effecteurs réactifs)
#
# sans Virtual DOM.Très rapide, rivalise
# avec Svelte.Communauté plus
#
# ### petite, mais active
#
# et enthousiasteComposants fonc-
#
# ### tionnels avec
#
# ### hooks, approche
#
# réactive fine-grain.
# Qwik Utilise un système
# de rendu "resu-
#
# ### mable" pour une
#
# ### hydratation opti-
#
# ### misée sans Virtual
#
# DOM.Ultra-rapide au
# rendu initial,
# charge dynamique
# du JavaScript,
# optimisé.Relativement
#
# ### nouveau mais en
#
# ### croissance. Miško
#
# ### Hevery, le créateur
#
# d’Angular.Syntaxe basée sur
#
# ### des composants
#
# avec une logique
# de "rendering on
# demand".
# Table 4.1 – Comparaison des librairies front-end
# Anthony Menghi & Mehdi Ghoulam 25 04/11/2024
#
# ---
#
# Cahier des charges
#
# ### Conclusion
#
# Nous avons choisi d’utiliser une combinaison de Solid.js etReactpour tirer parti des forces
# de chacune de ces librairies.
# Solid.js serautilisépourlespartiescritiquesdel’applicationoùlaperformanceestprimordiale,
# comme la gestion des états dans les sections liées au gameplay. Grâce à sa réactivité fine-grain et à
# l’absence de Virtual DOM, Solid.js offre des mises à jour rapides et directes du DOM, garantissant
# des performances exceptionnelles dans les scénarios exigeants.
# Enparallèle,nousintégrerons Reactpourtirerprofitdesonvasteécosystème,desacommunauté
# active et de sa bibliothèque de composants éprouvés. Cet écosystème riche nous permettra d’accé-
# lérer le développement des parties moins critiques en termes de performance, tout en bénéficiant de
# ressources abondantes et de solutions prêtes à l’emploi.
# Ces deux librairies coexisteront harmonieusement grâce à l’utilisation d’ Astro, un framework
# que nous détaillerons dans la section suivante. Astro permet de combiner différentes technologies
# front-end dans un même projet, assurant une intégration fluide entre Solid.js et React. Cette ap-
# proche hybride maximise la performance tout en tirant parti de la richesse de l’écosystème React,
# répondant ainsi parfaitement aux besoins variés de notre application.
# —Performance :Solid.jsoffredesperformancesoptimalesgrâceàsacompilationenJavaScript
# natif, particulièrement dans les scénarios nécessitant une gestion réactive et rapide des états.
# —Écosystème et communauté : React bénéficie d’un écosystème riche, d’une vaste com-
# ...
#
# ### 8.4 Processus de génération de cartes dans une collection
#
# ### existante avec gestion de token et clustering
#
# Figure 8.2 – Pipeline adaptatif de génération de flashcard
# Anthony Menghi & Mehdi Ghoulam 71 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# #### 8.4.1 Explication détaillée
#
# Le code définit une route POSTsur/cards/add/prompt qui permet de générer des flashcards
# basées sur une collection de documents et des paramètres utilisateurs. Voici les étapes détaillées :
#
# ## 1.Récupération de la collection
#
# Oncommence parrécupérerla collectionspécifiéepar leclientà l’aidede chroma_client .
# Les documents et leurs embeddings sont extraits pour une utilisation ultérieure.
#
# ## 2.Gestion des documents
#
# —Si aucun document n’existe :
# — Un prompt de génération de cartes est créé avec CardsPrompt .
# — Ce prompt est utilisé pour générer des cartes via MistralService .
# — Les cartes sont nettoyées et validées avant d’être renvoyées.
# —Si des documents existent :
# — Unpromptestgénéréenprenantencomptelesdocuments(via CardsPromptWithCollection ).
# —Calcul des tokens :
# — On compte le nombre de tokens total pour vérifier s’il est inférieur à la limite (80
# 000).
# — Si cette limite est respectée, les cartes sont générées directement.
# — Sinon :
# — Les documents sont divisés en clusters basés sur leurs embeddings.
# — Un résumé est généré pour chaque cluster avec ClusterSummaryPrompt .
# — Cesrésuméssontutiliséspourcréerunnouveauprompt( CardsPromptWithSummary ).
# — Les cartes sont générées et validées comme précédemment.
#
# ## 3.Clustering et résumés
#
# Quand la limite de tokens est dépassée :
# — Les documents sont divisés en groupes pour réduire la complexité.
# — Chaque groupe est résumé individuellement.
# — Ces résumés sont combinés en un seul prompt.
#
# ## 4.Gestion des exceptions
#
# Chaque étape critique est protégée par des blocs try/except :
# — Problèmes lors de la récupération des collections.
# — Erreurs dans la génération des prompts.
# — Échecs dans le comptage des tokens.
#
# ## 5.Services et méthodes
#
# Le code s’appuie sur des classes et fonctions auxiliaires :
# —CardsPrompt : Génération de prompt standard.
# —CardsPromptWithCollection : Intègre des documents existants.
# —ClusterSummaryPrompt : Crée un résumé par cluster.
# —MistralService : Génère des cartes basées sur les prompts.
# —clean_and_validate_cards : Vérifie la validité des cartes générées.
# Anthony Menghi & Mehdi Ghoulam 72 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# Point d’amélioration :
# Pouraméliorerleprocessusd’ajoutdeflashcardsdansunecollection,ilseraitpertinentd’intégrer
# une étape de vérification de pertinence basée sur une recherche de similarité sémantique. Voici
# comment cette optimisation pourrait être mise en œuvre :
#
# ## 1.Transformation des flashcards en embeddings
#
# Chaque flashcard générée par le LLM serait transformée en un embedding vectoriel.
# Cela permet de représenter son contenu sous une forme exploitable pour des comparaisons
# sémantiques. Cette opération peut être réalisée via des modèles de vectorisation adaptés (par
# exemple, SentenceTransformers ).
#
# ## 2.Recherche sémantique dans chroma
#
# Ces embeddings seraient ensuite comparés aux documents ou flashcards existants dans
# la base de données Chroma. La recherche de similarité sémantique permettrait d’identifier :
# — Les flashcards pertinentes par rapport au contenu de la collection.
# — Les flashcards redondantes ou hors sujet.
# Pour cela, une métrique comme la cosine similarity serait utilisée pour évaluer la proximité
# entre les embeddings. Un seuil configurable (par exemple, similarity_threshold ) détermi-
# nerait si une flashcard doit être ajoutée ou rejetée.
#
# ## 3.Pipeline de vérification et ajustement
#
# Une pipeline supplémentaire serait introduite pour gérer le flux des flashcards générées :
# —Vérification de pertinence :
# — Les flashcards rejetées (trop similaires ou non pertinentes) ne sont pas ajoutées à la
# collection.
# — Les flashcards pertinentes sont directement intégrées à la collection Chroma.
# —Itération du processus :
# — Si le nombre de flashcards requises n’est pas atteint après la première génération, une
# nouvelle itération est lancée.
# — Dans le nouveau prompt, les flashcards rejetées sont utilisées pour enrichir le contexte
# duprompt engineering . Cela peut inclure :
# — Une indication explicite des types de réponses à éviter.
# — Une reformulation pour clarifier les attentes et améliorer la précision des flashcards
# générées.
# —Répétition jusqu’à satisfaction :
# — Ce processus itératif est répété jusqu’à ce que le nombre de flashcards souhaité soit
# atteint, tout en respectant les critères de pertinence et de diversité.
#
# ## 4.Avantages et garanties
#
# Cette pipeline garantit plusieurs points cruciaux :
# — Pertinence : Les flashcards ajoutées sont en adéquation avec le contexte et les objectifs
# de la collection.
# —Non-redondance : Les doublons ou flashcards trop similaires sont évités, améliorant
# ainsi la qualité globale de la collection.
# —Adaptabilité : Grâce à l’ajustement dynamique du prompt, le LLM apprend à produire
# des réponses plus précises et adaptées aux besoins spécifiques.
# Anthony Menghi & Mehdi Ghoulam 73 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# —Efficacité : La gestion itérative permet d’atteindre le nombre exact de flashcards requis
# tout en maintenant un haut niveau de qualité.
#
# ### 8.5 Recherche de similarité
#
# La recherche de similarité est un élément central dans le fonctionnement de notre application.
# Elle constitue la base de plusieurs fonctionnalités clés, en particulier dans le cadre des algorithmes
# de recommandation. Cette technique est utilisée pour offrir une expérience personnalisée à chaque
# utilisateur en identifiant et en suggérant des éléments pertinents qui partagent des caractéristiques
# similaires avec ceux déjà appréciés ou créés par l’utilisateur.
#
# #### 8.5.1 Recommandation de contenus pour les utilisateurs
#
# L’un des cas d’utilisation les plus notables de la recherche de similarité est l’algorithme de
# recommandation de contenu. Par exemple, dans le fil d’actualités, la recherche de similarité per-
# met de proposer aux utilisateurs des contenus qui sont en phase avec leurs intérêts. En analysant
# les comportements, les interactions et les préférences des utilisateurs, nous pouvons générer des
# recommandations de :
# —Utilisateurs similaires : Identifier les profils d’utilisateurs qui partagent des intérêts ou des
# comportements similaires, favorisant ainsi les interactions sociales au sein de la plateforme.
# —Collections de contenu similaires : Suggérer des collections de flashcards, d’articles ou
# de contenus qui correspondent aux préférences ou aux thématiques suivies par l’utilisateur.
# —Contenus similaires : Proposer des flashcards, vidéos, articles ou autres types de contenu
# qui ont des caractéristiques communes avec ceux que l’utilisateur a déjà consultés ou aimés.
# Cette approche permet non seulement d’améliorer l’engagement utilisateur en offrant un contenu
# pertinent, mais aussi d’augmenter la satisfaction générale des utilisateurs en leur proposant des
# éléments qui enrichissent leur expérience.
#
# #### 8.5.2 Validation et pertinence des flashcards dans les collections
#
# Larecherchedesimilaritéjoueégalementunrôlecrucialdanslagestiondesflashcardsauseindes
# collections. Lorsqu’un utilisateur souhaite ajouter une nouvelle flashcard à une collection existante,
# il est primordial de vérifier la pertinence de cette flashcard par rapport aux éléments déjà présents
# dans la collection. Grâce à la similarité de contenu, nous pouvons effectuer plusieurs vérifications :
# —Vérification de similarité entre flashcards : Avant d’ajouter une nouvelle flashcard,
# nous comparons son contenu à celui des autres flashcards déjà présentes dans la collection
# pour garantir qu’elles ne soient pas redondantes et qu’elles apportent une valeur ajoutée.
# —Contrôle de cohérence thématique : Il est également important de valider si la nouvelle
# flashcard s’inscrit bien dans la thématique de la collection. Cela peut être fait en utilisant
# des techniques avancées de traitement du langage naturel (NLP), comme la vectorisation de
# texte, pour calculer la similarité sémantique entre les flashcards.
# Anthony Menghi & Mehdi Ghoulam 74 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# —Optimisation de l’expérience utilisateur : En évitant la duplication d’informations ou
# la création de collections incohérentes, cette fonctionnalité permet d’optimiser l’organisation
# et la qualité des contenus proposés à l’utilisateur, ce qui améliore l’expérience globale.
#
# ### 8.6 Mise en pratique
#
# Nous pouvons facilement rechercher les documents similaires dans une collection Chroma en
# faisant une requête :
#
# ### collection.query(
#
# query_embeddings=embeddings,
# n_results=X
# )
# Ensuite, avec de la transformation de données en Python, nous pouvons obtenir un fichier
# JSON valide qui associe, pour chaque document (flashcard) de la collection, ses trois documents
# (flashcards) les plus similaires avec leur identifiant et leur taux de similarité.
# [
# {
# "card": "1",
# "similar_card": [
# {
# "card_id": "7",
# "distance": 29.73105777006491
# },
# {
# "card_id": "3",
# "distance": 30.220916649358344
# },
# {
# "card_id": "99",
# "distance": 31.230436378484125
# }
# ]
# },
# {
# "card": "2",
# "similar_card": [
# {
# "card_id": "5",
# "distance": 7.982424170414841
# },
# {
# Anthony Menghi & Mehdi Ghoulam 75 04/11/2024
#
# ---
#
# Cahier des charges
# "card_id": "6",
# "distance": 8.682401374344815
# },
# {
# "card_id": "4",
# "distance": 10.285412631616909
# }
# ]
# }
# ]
# Cette similarité est calculée à l’aide de l’équation de la distance au carré dans l’espace euclidien.
# Il existe cependant plusieurs façons de calculer cette distance, telles que le produit scalaire (Inner
# Product) ou la similarité cosinus (Cosine Similarity). Nous avons choisi l’équation de la distance au
# carré dans l’espace euclidien car elle permet de mesurer efficacement la similarité entre les vecteurs
# tout en étant simple à implémenter et à interpréter. De plus, cette méthode est particulièrement
# adaptée pour des données à dimensions multiples, car elle prend en compte la distance globale
# entre les points tout en évitant de se concentrer sur des valeurs individuelles, ce qui permet une
# comparaison robuste et précise des documents. La distance euclidienne au carré entre deux points
# xetydans un espace à ndimensions est donnée par :
# d2(x,y) =n/summationdisplay
#
# ### i=1(xi−yi)2
#
# oùx= (x1, x2, . . . , x n)ety= (y1, y2, . . . , y n)sont les coordonnées des deux points dans l’espace.
# ChromaDB,quantàlui,gèreautomatiquementlescalculsdedistancesentrelesvecteursdemanière
# transparente, ce qui simplifie grandement l’implémentation et optimise les performances.
# Anthony Menghi & Mehdi Ghoulam 76 04/11/2024
#
# ---
#
# Cahier des charges
# Chapitre 9
#
# ### Conclusion
#
# Ce cahier des charges a présenté en détail les différentes étapes de conception et de mise en
# œuvre du projet Mindlet , une application innovante dédiée à l’apprentissage interactif et collabo-
# ratif. Le projet a intégré des technologies avancées, une architecture solide et une approche centrée
# sur l’utilisateur, pour créer une expérience d’apprentissage fluide, immersive et accessible.
# Initialement, nous avons défini les objectifs pédagogiques, technologiques et entrepreneuriaux
# deMindlet . Ces objectifs visent à offrir une solution flexible et engageante dans le domaine de
# l’éducation en ligne, en utilisant l’intelligence artificielle pour automatiser la création de contenu
# éducatif tout en favorisant l’apprentissage collaboratif. Nous avons aussi pris en compte les oppor-
# tunités d’innovation identifiées dans les applications concurrentes comme Anki, Quizlet et Duolingo,
# afin de proposer une alternative adaptée aux besoins des utilisateurs.
# Sur le plan technologique, le développement de Mindlet s’est appuyé sur des choix stratégiques
# pour garantir une architecture moderne, performante et évolutive. L’application mobile a été réa-
# lisée avec React Native , permettant de couvrir les plateformes web, mobile et desktop. Cette
# technologie a été choisie pour sa flexibilité, ainsi que pour la possibilité d’intégrer des fonctionnali-
# tés natives en SwiftetKotlinsi nécessaire. La gestion de la navigation, des composants UI, ainsi
# que l’utilisation de Tailwind CSS pour la mise en page ont permis de créer une interface fluide et
# intuitive.
# La gestion des données et des interactions avec l’API a été soigneusement mise en place, no-
# tamment à travers la gestion des états locaux et des requêtes API en utilisant SWR (Stale-
# While-Revalidate) . Cela a permis de garantir une gestion optimale des données et une expérience
# utilisateur réactive. Les erreurs et les états de chargement ont été traités de manière robuste afin
# d’offrir une application stable et fiable. En parallèle, une attention particulière a été portée à l’ac-
# cessibilité, garantissant ainsi que l’application soit utilisée par un large public.
# Une partie essentielle du projet a été le développement de l’API publique de Mindlet , qui
# permet de gérer les entités telles que les Collections, les Cartes ou encore les parties de jeux. Les
# opérations CRUD ont été mises en œuvre pour assurer une gestion efficace des données. La vali-
# dation des données a été réalisée à l’aide de Zod, garantissant ainsi la sécurité et l’intégrité des
# Anthony Menghi & Mehdi Ghoulam 77 04/11/2024
#
# ---
#
# ### Cahier des charges
#
# informations. La gestion des erreurs dans l’API a été conçue pour offrir une expérience cohérente
# et sécurisée, tout en facilitant la gestion des échecs avec des messages d’erreurs clairs et précis. La
# documentation de l’API a été intégrée avec OpenAPI , offrant une interface claire pour les déve-
# loppeurs et facilitant l’intégration avec d’autres systèmes.
# En parallèle, nous avons développé une API privée dédiée à l’intelligence artificielle et à l’analyse
# sémantique. Cette API repose sur une architecture robuste et modulaire, permettant une gestion
# optimale des données et des interactions avec les services d’IA. Nous avons conçu un système de
# prompt engineering en utilisant les principes de la programmation orientée objet (OOP), afin de
# garantir une flexibilité maximale dans la génération des prompts et des interactions avec les mo-
# dèles de langage. L’intégration de FastAPI a permis d’optimiser les performances et de faciliter
# l’interfaçage avec la base de données ChromaDB , qui gère les informations et les résultats des
# processus de clustering.
# Le processus de génération de cartes dans une collection a été conçu pour intégrer des concepts
# d’intelligence artificielle avancée, comme la gestion de tokens et le clustering des données. Cette ap-
# proche a permis d’améliorer la pertinence des contenus générés et la personnalisation de l’apprentis-
# sage. Nous avons également développé un système de recommandation de contenus et d’utilisateurs
# basé sur la similarité, qui utilise des techniques avancées pour valider la pertinence des cartes dans
# les collections. Cette fonctionnalité a été mise en pratique avec des exemples concrets, en incluant
# des explications détaillées du code et des schémas pour illustrer les processus techniques et les flux
# de données.
# En conclusion, Mindlet se positionne comme une solution novatrice dans le domaine de l’ap-
# prentissage en ligne, grâce à une architecture solide et flexible qui intègre des fonctionnalités avan-
# cées d’intelligence artificielle et d’analyse sémantique. Le projet a su allier technologies de pointe,
# réflexion pédagogique et prise en compte des besoins des utilisateurs pour offrir une expérience d’ap-
# prentissage moderne, sécurisée et collaborative. Les choix technologiques judicieux, l’architecture
# performante et l’approche centrée sur l’utilisateur permettent à Mindlet de répondre aux attentes
# pédagogiques tout en étant flexible, évolutif et sécurisé. Le succès du projet repose sur la rigueur de
# son exécution et une stratégie marketing bien pensée pour attirer et fidéliser une large communauté
# d’utilisateurs.
# Anthony Menghi & Mehdi Ghoulam 78 04/11/2024
#
# ---
#
# Cahier des charges
#
# ### Table des figures
#
# Anthony Menghi & Mehdi Ghoulam 79 04/11/2024

# %% [markdown]
# ## Sauvegarde du Markdown dans un fichier

# %%
# Sauvegarder le résultat dans un fichier .md
if result["parsed_markdown"]:
    output_filename = pdf_filename.replace(".pdf", ".md")
    output_path = Path("ressources") / output_filename
    
    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(result["parsed_markdown"])
    
    print(f"\n💾 Fichier Markdown sauvegardé: {output_path}")
else:
    print("\n⚠️ Aucun contenu à sauvegarder.")
# Out:
# 💾 Fichier Markdown sauvegardé: ressources\main.md

# %% [markdown]
# ## Détails par page (optionnel)

# %%
# Afficher les détails de chaque page
if result["parsed_pages"]:
    print("\n" + "="*50)
    print("DÉTAILS PAR PAGE:")
    print("="*50)
    
    for page in result["parsed_pages"]:
        print(f"\nPage {page.page_number}:")
        print(f"  - Caractères: {page.char_count}")
        print(f"  - Mots: {page.word_count}")
        print(f"  - Tableaux détectés: {'Oui' if page.has_tables else 'Non'}")
        print(f"  - Qualité: {page.extraction_quality:.0%}")
# Out:
# ==================================================
# DÉTAILS PAR PAGE:
# ==================================================
#
# Page 1:
#   - Caractères: 0
#   - Mots: 0
#   - Tableaux détectés: Non
#   - Qualité: 0%
#
# Page 2:
#   - Caractères: 87
#   - Mots: 14
#   - Tableaux détectés: Non
#   - Qualité: 97%
#
# Page 3:
#   - Caractères: 2067
#   - Mots: 274
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 4:
#   - Caractères: 1001
#   - Mots: 141
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 5:
#   - Caractères: 1945
#   - Mots: 280
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 6:
#   - Caractères: 2919
#   - Mots: 374
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 7:
#   - Caractères: 2468
#   - Mots: 329
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 8:
#   - Caractères: 1450
#   - Mots: 179
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 9:
#   - Caractères: 2343
#   - Mots: 320
#   - Tableaux détectés: Non
#   - Qualité: 100%
#
# Page 10:
#   - Caractères: 2422
#   - Mots: 321
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 11:
#   - Caractères: 2479
#   - Mots: 332
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 12:
#   - Caractères: 2180
#   - Mots: 317
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 13:
#   - Caractères: 909
#   - Mots: 123
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 14:
#   - Caractères: 1964
#   - Mots: 279
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 15:
#   - Caractères: 3087
#   - Mots: 431
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 16:
#   - Caractères: 1883
#   - Mots: 268
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 17:
#   - Caractères: 141
#   - Mots: 21
#   - Tableaux détectés: Non
#   - Qualité: 97%
#
# Page 18:
#   - Caractères: 1429
#   - Mots: 196
#   - Tableaux détectés: Non
#   - Qualité: 98%
#
# Page 19:
#   - Caractères: 3371
#   - Mots: 482
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 20:
#   - Caractères: 3337
#   - Mots: 458
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 21:
#   - Caractères: 1943
#   - Mots: 282
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 22:
#   - Caractères: 115
#   - Mots: 19
#   - Tableaux détectés: Non
#   - Qualité: 97%
#
# Page 23:
#   - Caractères: 1923
#   - Mots: 265
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 24:
#   - Caractères: 976
#   - Mots: 137
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 25:
#   - Caractères: 1797
#   - Mots: 261
#   - Tableaux détectés: Non
#   - Qualité: 100%
#
# Page 26:
#   - Caractères: 1837
#   - Mots: 257
#   - Tableaux détectés: Non
#   - Qualité: 100%
#
# Page 27:
#   - Caractères: 1795
#   - Mots: 228
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 28:
#   - Caractères: 1908
#   - Mots: 273
#   - Tableaux détectés: Non
#   - Qualité: 100%
#
# Page 29:
#   - Caractères: 2585
#   - Mots: 388
#   - Tableaux détectés: Non
#   - Qualité: 100%
#
# Page 30:
#   - Caractères: 1800
#   - Mots: 236
#   - Tableaux détectés: Non
#   - Qualité: 100%
#
# Page 31:
#   - Caractères: 2398
#   - Mots: 324
#   - Tableaux détectés: Non
#   - Qualité: 100%
#
# Page 32:
#   - Caractères: 1300
#   - Mots: 178
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 33:
#   - Caractères: 1323
#   - Mots: 192
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 34:
#   - Caractères: 1970
#   - Mots: 260
#   - Tableaux détectés: Non
#   - Qualité: 100%
#
# Page 35:
#   - Caractères: 2460
#   - Mots: 352
#   - Tableaux détectés: Non
#   - Qualité: 100%
#
# Page 36:
#   - Caractères: 1808
#   - Mots: 261
#   - Tableaux détectés: Non
#   - Qualité: 100%
#
# Page 37:
#   - Caractères: 1759
#   - Mots: 249
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 38:
#   - Caractères: 2479
#   - Mots: 334
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 39:
#   - Caractères: 733
#   - Mots: 101
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 40:
#   - Caractères: 1815
#   - Mots: 267
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 41:
#   - Caractères: 2464
#   - Mots: 352
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 42:
#   - Caractères: 1051
#   - Mots: 162
#   - Tableaux détectés: Non
#   - Qualité: 100%
#
# Page 43:
#   - Caractères: 1336
#   - Mots: 159
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 44:
#   - Caractères: 1538
#   - Mots: 205
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 45:
#   - Caractères: 1582
#   - Mots: 227
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 46:
#   - Caractères: 364
#   - Mots: 51
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 47:
#   - Caractères: 1489
#   - Mots: 194
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 48:
#   - Caractères: 1830
#   - Mots: 257
#   - Tableaux détectés: Non
#   - Qualité: 98%
#
# Page 49:
#   - Caractères: 1474
#   - Mots: 193
#   - Tableaux détectés: Non
#   - Qualité: 98%
#
# Page 50:
#   - Caractères: 1876
#   - Mots: 276
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 51:
#   - Caractères: 1667
#   - Mots: 238
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 52:
#   - Caractères: 1995
#   - Mots: 302
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 53:
#   - Caractères: 2278
#   - Mots: 329
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 54:
#   - Caractères: 2215
#   - Mots: 360
#   - Tableaux détectés: Non
#   - Qualité: 98%
#
# Page 55:
#   - Caractères: 2083
#   - Mots: 338
#   - Tableaux détectés: Non
#   - Qualité: 98%
#
# Page 56:
#   - Caractères: 1848
#   - Mots: 274
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 57:
#   - Caractères: 2543
#   - Mots: 379
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 58:
#   - Caractères: 2715
#   - Mots: 425
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 59:
#   - Caractères: 2240
#   - Mots: 340
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 60:
#   - Caractères: 1845
#   - Mots: 288
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 61:
#   - Caractères: 1705
#   - Mots: 265
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 62:
#   - Caractères: 2104
#   - Mots: 284
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 63:
#   - Caractères: 2367
#   - Mots: 329
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 64:
#   - Caractères: 2096
#   - Mots: 272
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 65:
#   - Caractères: 2442
#   - Mots: 340
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 66:
#   - Caractères: 1370
#   - Mots: 183
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 67:
#   - Caractères: 1804
#   - Mots: 248
#   - Tableaux détectés: Non
#   - Qualité: 98%
#
# Page 68:
#   - Caractères: 1805
#   - Mots: 240
#   - Tableaux détectés: Non
#   - Qualité: 98%
#
# Page 69:
#   - Caractères: 1723
#   - Mots: 209
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 70:
#   - Caractères: 2201
#   - Mots: 315
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 71:
#   - Caractères: 715
#   - Mots: 115
#   - Tableaux détectés: Non
#   - Qualité: 98%
#
# Page 72:
#   - Caractères: 241
#   - Mots: 38
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 73:
#   - Caractères: 2162
#   - Mots: 312
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 74:
#   - Caractères: 2698
#   - Mots: 383
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 75:
#   - Caractères: 3049
#   - Mots: 419
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 76:
#   - Caractères: 1098
#   - Mots: 149
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 77:
#   - Caractères: 1340
#   - Mots: 194
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 78:
#   - Caractères: 2610
#   - Mots: 393
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 79:
#   - Caractères: 2670
#   - Mots: 393
#   - Tableaux détectés: Non
#   - Qualité: 99%
#
# Page 80:
#   - Caractères: 87
#   - Mots: 14
#   - Tableaux détectés: Non
#   - Qualité: 97%
